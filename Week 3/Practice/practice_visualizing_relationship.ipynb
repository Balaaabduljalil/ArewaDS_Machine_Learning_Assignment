# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.figure import figure
honey = pd.read_csv('honey.csv')
honey.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
sns.relplot(x="priceperlb",y="state",data=honey,height=15,aspect=.5);

# %%
sns.relplot(x="priceperlb",y="state",hue="year",palette="YlOrBr",data=honey,height=15,aspect=.5);

# %%
sns.relplot(x="priceperlb",y="state",size="year",data=honey,height=15,aspect=.5);

# %%
sns.relplot(x="year",y="priceperlb",kind="line",data=honey);
# Out:
# C:\Users\BALA ABDULJALIL\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.relplot(x="year",y="totalprod",kind="line",data=honey);

# %%
sns.relplot(
    data=honey,
    x="yieldpercol",y="numcol",
    col="year",
    col_wrap=3,
    kind="line")

# %%
fig, ax = plt.subplots(figure=(12,6))
lineplot = sns.lineplot(x=honey['year'],y=['numcol'],data=honey,label='Number of bee colonies',legend=False)
sns.spine()
plt.ylabel('# colonies')
plt.title('Honey Production Year over Year');
ax2 = ax.twinx()
lineplot2 = sns.lineplot(x=honey['year'],y=honey['yieldpercol'],ax=ax2,color="r",label='Yield per colony',legend=False)
sns.despine(right=False)
plt.ylabel('colony yield')
ax.figure.legend();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-3d284d062b4d> in <module>
# ----> 1 fig, ax = plt.subplots(figure=(12,6))
#       2 lineplot = sns.lineplot(x=honey['year'],y=['numcol'],data=honey,label='Number of bee colonies',legend=False)
#       3 sns.spine()
#       4 plt.ylabel('# colonies')
#       5 plt.title('Honey Production Year over Year');
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1215
#    1216     """
# -> 1217     fig = figure(**fig_kw)
#    1218     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1219                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# ...
