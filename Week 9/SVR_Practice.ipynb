# %%
# !pip install -U scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in c:\users\bala abduljalil\appdata\local\continuum\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\bala abduljalil\appdata\local\continuum\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\bala abduljalil\appdata\local\continuum\anaconda3\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.14.6 in c:\users\bala abduljalil\appdata\local\continuum\anaconda3\lib\site-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied, skipping upgrade: scipy>=1.1.0 in c:\users\bala abduljalil\appdata\local\continuum\anaconda3\lib\site-packages (from scikit-learn) (1.7.3)

# %%
import sys
sys.path.append('../../')

# %%
import os
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
import math

from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler

# %%
energy = pd.read_csv('energy.csv')
energy.head(10)
# Out:
#              timestamp    load       temp
# 0  2012-01-01 00:00:00  2698.0  32.000000
# 1  2012-01-01 01:00:00  2558.0  32.666667
# 2  2012-01-01 02:00:00  2444.0  30.000000
# 3  2012-01-01 03:00:00  2402.0  31.000000
# 4  2012-01-01 04:00:00  2403.0  32.000000
# 5  2012-01-01 05:00:00  2453.0  31.333333
# 6  2012-01-01 06:00:00  2560.0  30.000000
# 7  2012-01-01 07:00:00  2719.0  29.000000
# 8  2012-01-01 08:00:00  2916.0  29.000000
# 9  2012-01-01 09:00:00  3105.0  33.333333

# %%
energy.plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %%
train_start_dt = '2014-11-01 00:00:00'
test_start_dt = '2014-12-30 00:00:00'

# %%
# Create model using RBF kernel

model = SVR(kernel='rbf',gamma=0.5,C=10,epsilon=0.05)
