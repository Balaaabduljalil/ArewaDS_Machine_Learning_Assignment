# %% [markdown]
# ## IRIS DATASET VISUALIZATION USING PANDAS AND MATPLOTLIB.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Iris.csv")

# %%
print (df.head(10))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# ## PLOTTING THE GRAPH USING MATPLOTLIB.

# %%
import pandas as pd
import matplotlib.pyplot as plt
Iris = pd.read_csv("Iris.csv")
plt.plot(Iris.Id,Iris["SepalLengthCm"],"r--")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ##  VISUALIZATION USING SCATTER PLOT

# %%
Iris.plot(kind = "scatter", x = "SepalLengthCm", y = "PetalLengthCm")
plot.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6cdc59fd4c1a> in <module>
#       1 Iris.plot(kind = "scatter", x = "SepalLengthCm", y = "PetalLengthCm")
# ----> 2 plot.grid()
#
# NameError: name 'plot' is not defined
