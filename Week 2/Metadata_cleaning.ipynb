# %%
import pandas as pd

# %%
df = pd.read_csv("metadata.csv")

# %%
df
# Out:
#      cord_uid                                                sha  \
# 0    4429oz9s                                                NaN
# 1    sjdy79ok                                                NaN
# 2    qa5n3xpi                                                NaN
# 3    jasf7agm           4d4a64f98aac069dd375c8a82d84808fcd7493d8
# 4    dagq84tr           464b915e6d545b37d65ac58cecf42512b11a92e2
# 5    y90u066y                                                NaN
# 6    nsbg4260                                                NaN
# 7    5uqntmo8                                                NaN
# 8    r4klffp5                                                NaN
# 9    qt0q3aew           12ffda3fc9093df578b0e56f7c12dbeee0302842
# 10   yrov0mb2                                                NaN
# 11   xeq9a21a                                                NaN
# 12   bymxmnhm                                                NaN
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [cord_uid, sha, source_x, title, doi, pmcid, pubmed_id, license, abstract, publish_time, authors, journal, mag_id, who_covidence_id, arxiv_id, pdf_json_files, pmc_json_files, url, s2_id]
# Index: []

# %%
df2 = pd.read_csv("metadata.csv")

# %%
df2
# Out:
#      cord_uid                                                sha  \
# 0    4429oz9s                                                NaN
# 1    sjdy79ok                                                NaN
# 2    qa5n3xpi                                                NaN
# 3    jasf7agm           4d4a64f98aac069dd375c8a82d84808fcd7493d8
# 4    dagq84tr           464b915e6d545b37d65ac58cecf42512b11a92e2
# 5    y90u066y                                                NaN
# 6    nsbg4260                                                NaN
# 7    5uqntmo8                                                NaN
# 8    r4klffp5                                                NaN
# 9    qt0q3aew           12ffda3fc9093df578b0e56f7c12dbeee0302842
# 10   yrov0mb2                                                NaN
# 11   xeq9a21a                                                NaN
# 12   bymxmnhm                                                NaN
# ...

# %%
df2 = df2[df2["pdf_json_files"].notna()]

# %%
df2
# Out:
#      cord_uid                                                sha  \
# 3    jasf7agm           4d4a64f98aac069dd375c8a82d84808fcd7493d8
# 4    dagq84tr           464b915e6d545b37d65ac58cecf42512b11a92e2
# 9    qt0q3aew           12ffda3fc9093df578b0e56f7c12dbeee0302842
# 14   rkncmeld           47772454c747b6aac91e6a7575e681e7639d4775
# 15   r0qntwbc           74f6313a253eaa8406c5d653bf5e82525df788ca
# 16   ku2bmqio  1911c66dd91577c9a328a1f7da286c9bbd657502; 658e...
# 18   8pgcbspo           16f3fa50801123b04aef8e6a1ef30d670f14d8f7
# 20   rdjwpwwo  1e512f9dbabc18bf98189e8f35ba04e1464a9a76; 4782...
# 22   o7tjhy35           d57e745118d4c1c7d0b7ae6731e8e57c22993541
# 25   k14fbaoz           0289adf2571753ce52e952985de4e0248df4e3ac
# 28   nydo2wm2           c43df5354c7813c40419f215fb89ff0abb34d907
# 37   5ortlmfo           07633c2cbaf907f6c180fc69286b3c6660644187
# 38   lomyufw8           c553adc1b77446dae2659b7389713a2100996a74
# ...
